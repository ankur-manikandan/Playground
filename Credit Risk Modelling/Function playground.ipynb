# %%
# %matplotlib notebook

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

SEED = 42
np.random.seed(SEED)
# Out:
# /Users/ankurmanikandan/anaconda3/lib/python3.7/importlib/_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)

# %%
log_vals = np.log(range(50000))

fig, ax = plt.subplots()
plt.plot(log_vals)
plt.show()
# Out:
# /Users/ankurmanikandan/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: RuntimeWarning: divide by zero encountered in log
#   """Entry point for launching an IPython kernel.
# <img src="data:image/png;base64,..." width="640">

# %%
x = range(-100, 10)
exp_vals = np.exp(x)

fig, ax = plt.subplots()
plt.plot(x, exp_vals)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
