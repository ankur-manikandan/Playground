# %%
# %matplotlib notebook

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
ts = pd.Series(np.random.randn(1000),
              index=pd.date_range('1/1/2000', periods=1000))
ts = ts.cumsum()

# %%
fig, ax = plt.subplots()
ts.plot(ax=ax)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
df2 = pd.DataFrame(np.random.rand(10, 4), columns=['a', 'b', 'c', 'd'])

# %%
fig, ax = plt.subplots()
df2.plot(ax=ax)
plt.show()

fig, ax = plt.subplots()
df2.plot.bar(ax=ax)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %%
df2 = pd.DataFrame(np.random.rand(1000, 4), columns=['a', 'b', 'c', 'd'])

fig, ax = plt.subplots()
df2.hist(ax=ax)
plt.show()

df2.corr()
# Out:
# <img src="data:image/png;base64,..." width="640">
# /Users/ankurmanikandan/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared
#   after removing the cwd from sys.path.
#           a         b         c         d
# a  1.000000  0.013008 -0.030569 -0.007130
# b  0.013008  1.000000 -0.053514  0.025235
# c -0.030569 -0.053514  1.000000  0.020131
# d -0.007130  0.025235  0.020131  1.000000

# %%
from pandas.plotting import scatter_matrix

fig, ax = plt.subplots()
scatter_matrix(df2)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %%
fig, ax = plt.subplots()
df2.plot.hist(ax=ax, alpha=0.3)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig, ax = plt.subplots()
df2.boxplot(ax=ax)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig, ax = plt.subplots()
df2.plot(subplots=True)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %%
fig, ax = plt.subplots()
df2.a.plot(ax=ax, alpha=0.3)
df2.b.plot(secondary_y=True, ax=ax, alpha=0.3)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
df3 = pd.DataFrame(np.random.rand(50, 4), columns=['a', 'b', 'c', 'd'])

# %%
# fig, ax = plt.subplots(nrows=2, ncols=1)
# df3.plot.scatter(x='a', y='b')
# plt.show()

fig, ax = plt.subplots()
df3.groupby('class')['a', 'b'].count().plot.bar(ax=ax, subplots=True)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# /Users/ankurmanikandan/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# /Users/ankurmanikandan/anaconda3/lib/python3.7/site-packages/pandas/plotting/_matplotlib/__init__.py:61: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared
#   plot_obj.generate()

# %%
fig, ax = plt.subplots()
df3.plot.scatter(x='a', y='b', color='blue', label='points A', ax=ax)
df3.plot.scatter(x='c', y='d', color='green', label='points B', ax=ax)
plt.margins(0.1)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
df3.head()
# Out:
#           a         b         c         d
# 0  0.758837  0.392426  0.905002  0.250956
# 1  0.859991  0.261547  0.505373  0.949216
# 2  0.395004  0.127446  0.418196  0.198274
# 3  0.541981  0.912007  0.268561  0.213273
# 4  0.104114  0.726062  0.632334  0.479816

# %%
df3['class'] = np.random.choice(['y', 'n'], p=[0.2, 0.8], size=len(df3), replace=True)
df3.head()
# Out:
#           a         b         c         d class
# 0  0.758837  0.392426  0.905002  0.250956     n
# 1  0.859991  0.261547  0.505373  0.949216     n
# 2  0.395004  0.127446  0.418196  0.198274     n
# 3  0.541981  0.912007  0.268561  0.213273     y
# 4  0.104114  0.726062  0.632334  0.479816     n

# %%
fig, ax = plt.subplots()
df3.groupby('class')['a', 'b'].count().plot.bar(ax=ax)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# /Users/ankurmanikandan/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.

# %%
fig, ax = plt.subplots()
df3.loc[(df3['class'] == 'y'), 'a'].hist(label='yes', ax=ax)
df3.loc[(df3['class'] == 'n'), 'b'].hist(label='no', ax=ax, alpha=0.3)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig, ax = plt.subplots()
df3.loc[df3['class'] == 'y'].plot.scatter(x='a', y='b', color='green', label='yes', ax=ax)
df3.loc[df3['class'] == 'n'].plot.scatter(x='a', y='b', color='red', label='no', ax=ax)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
df = pd.DataFrame({'a': [1, 22, 31, 44, 52, 64, 7, 80, 9]})

# %%
df['diff_val'] = df.diff()
df
# Out:
#     a  diff_val
# 0   1       NaN
# 1  22      21.0
# 2  31       9.0
# 3  44      13.0
# 4  52       8.0
# 5  64      12.0
# 6   7     -57.0
# 7  80      73.0
# 8   9     -71.0

# %%
df['cumsum_val'] = df.diff_val.cumsum()
df
# Out:
#     a  diff_val  cumsum_val
# 0   1       NaN         NaN
# 1  22      21.0        21.0
# 2  31       9.0        30.0
# 3  44      13.0        43.0
# 4  52       8.0        51.0
# 5  64      12.0        63.0
# 6   7     -57.0         6.0
# 7  80      73.0        79.0
# 8   9     -71.0         8.0
