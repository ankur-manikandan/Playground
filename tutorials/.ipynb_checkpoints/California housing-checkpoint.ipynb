# %%
# %matplotlib notebook

import tensorflow as tf
from tensorflow import keras
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import fetch_california_housing
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
housing = fetch_california_housing()
# Out:
# Downloading Cal. housing from https://ndownloader.figshare.com/files/5976036 to /Users/ankurmanikandan/scikit_learn_data

# %%
housing
# Out:
# {'data': array([[   8.3252    ,   41.        ,    6.98412698, ...,    2.55555556,
#            37.88      , -122.23      ],
#         [   8.3014    ,   21.        ,    6.23813708, ...,    2.10984183,
#            37.86      , -122.22      ],
#         [   7.2574    ,   52.        ,    8.28813559, ...,    2.80225989,
#            37.85      , -122.24      ],
#         ...,
#         [   1.7       ,   17.        ,    5.20554273, ...,    2.3256351 ,
#            39.43      , -121.22      ],
#         [   1.8672    ,   18.        ,    5.32951289, ...,    2.12320917,
#            39.43      , -121.32      ],
#         [   2.3886    ,   16.        ,    5.25471698, ...,    2.61698113,
#            39.37      , -121.24      ]]),
#  'target': array([4.526, 3.585, 3.521, ..., 0.923, 0.847, 0.894]),
#  'feature_names': ['MedInc',
#   'HouseAge',
#   'AveRooms',
#   'AveBedrms',
#   'Population',
#   'AveOccup',
#   'Latitude',
#   'Longitude'],
#  'DESCR': '.. _california_housing_dataset:\n\nCalifornia Housing dataset\n--------------------------\n\n**Data Set Characteristics:**\n\n    :Number of Instances: 20640\n\n    :Number of Attributes: 8 numeric, predictive attributes and the target\n\n    :Attribute Information:\n        - MedInc        median income in block\n        - HouseAge      median house age in block\n        - AveRooms      average number of rooms\n        - AveBedrms     average number of bedrooms\n        - Population    block population\n        - AveOccup      average house occupancy\n        - Latitude      house block latitude\n        - Longitude     house block longitude\n\n    :Missing Attribute Values: None\n\nThis dataset was obtained from the StatLib repository.\nhttp://lib.stat.cmu.edu/datasets/\n\nThe target variable is the median house value for California districts.\n\nThis dataset was derived from the 1990 U.S. census, using one row per census\nblock group. A block group is the smallest geographical unit for which the U.S.\nCensus Bureau publishes sample data (a block group typically has a population\nof 600 to 3,000 people).\n\nIt can be downloaded/loaded using the\n:func:`sklearn.datasets.fetch_california_housing` function.\n\n.. topic:: References\n\n    - Pace, R. Kelley and Ronald Barry, Sparse Spatial Autoregressions,\n      Statistics and Probability Letters, 33 (1997) 291-297\n'}

# %%
X_train, X_test, y_train, y_test = train_test_split(housing.data, housing.target)
X_train, X_valid, y_train, y_valid = train_test_split(X_train, y_train)

# %%
X_train[:10]
# Out:
# array([[ 4.43970000e+00,  1.60000000e+01,  5.61501597e+00,
#          1.00000000e+00,  1.76400000e+03,  2.81789137e+00,
#          3.80600000e+01, -1.22170000e+02],
#        [ 4.33510000e+00,  2.10000000e+01,  4.21199214e+00,
#          1.05701180e+00,  7.27300000e+03,  2.38302752e+00,
#          3.74000000e+01, -1.22060000e+02],
#        [ 4.63750000e+00,  2.80000000e+01,  6.28177966e+00,
#          1.12923729e+00,  1.59100000e+03,  3.37076271e+00,
#          3.80000000e+01, -1.22020000e+02],
#        [ 5.04930000e+00,  4.00000000e+00,  7.94705882e+00,
#          1.19647059e+00,  2.86600000e+03,  3.37176471e+00,
#          3.38700000e+01, -1.17500000e+02],
#        [ 5.51960000e+00,  4.50000000e+01,  5.44444444e+00,
#          1.01234568e+00,  1.47400000e+03,  2.59964727e+00,
#          3.38300000e+01, -1.18130000e+02],
#        [ 6.07670000e+00,  1.60000000e+01,  5.57241379e+00,
#          9.44827586e-01,  3.71000000e+02,  2.55862069e+00,
#          3.83800000e+01, -1.22020000e+02],
#        [ 7.92130000e+00,  4.40000000e+01,  6.44811321e+00,
#          9.78773585e-01,  1.05700000e+03,  2.49292453e+00,
#          3.41300000e+01, -1.18180000e+02],
#        [ 3.72500000e+00,  3.40000000e+01,  5.49299065e+00,
#          1.02803738e+00,  1.06300000e+03,  2.48364486e+00,
#          3.66200000e+01, -1.21930000e+02],
#        [ 4.45610000e+00,  1.20000000e+01,  6.09487459e+00,
#          1.02617230e+00,  3.01800000e+03,  3.29116685e+00,
#          3.54100000e+01, -1.19120000e+02],
#        [ 3.68750000e+00,  1.70000000e+01,  1.00337079e+01,
#          1.93033708e+00,  8.53000000e+02,  1.91685393e+00,
#          3.38400000e+01, -1.16520000e+02]])

# %%
np.max(X_train)
# Out:
# 96.67068422289202

# %%
y_train[:10]
# Out:
# array([1.871, 2.674, 1.782, 2.398, 2.276, 2.164, 4.778, 2.78 , 0.969,
#        1.304])

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_valid = scaler.fit_transform(X_valid)
X_test = scaler.fit_transform(X_test)

# %%
X_train[:10]
# Out:
# array([[ 3.01289370e-01, -9.98530625e-01,  6.95702646e-02,
#         -2.15792106e-01,  2.79557748e-01, -2.30541176e-02,
#          1.13537100e+00, -1.28845378e+00],
#        [ 2.46194433e-01, -6.01922304e-01, -4.91630324e-01,
#         -9.06353708e-02,  4.93403045e+00, -5.69501982e-02,
#          8.25514269e-01, -1.23364223e+00],
#        [ 4.05474632e-01, -4.66706537e-02,  3.36271487e-01,
#          6.79196575e-02,  1.33392604e-01,  2.00402242e-02,
#          1.10720220e+00, -1.21371076e+00],
#        [ 6.22378026e-01, -1.95039060e+00,  1.00237253e+00,
#          2.15515436e-01,  1.21062126e+00,  2.01183261e-02,
#         -8.31749738e-01,  1.03854557e+00],
#        [ 8.70094553e-01,  1.30179764e+00,  1.34274034e-03,
#         -1.88689910e-01,  3.45410329e-02, -4.00654646e-02,
#         -8.50528934e-01,  7.24624885e-01],
#        [ 1.16353040e+00, -9.98530625e-01,  5.25296638e-02,
#         -3.36910887e-01, -8.97367369e-01, -4.32633394e-02,
#          1.28560456e+00, -1.21371076e+00],
#        [ 2.13511855e+00,  1.22247598e+00,  4.02803845e-01,
#         -2.62389986e-01, -3.17776105e-01, -4.83841200e-02,
#         -7.09684967e-01,  6.99710545e-01],
#        [-7.51575835e-02,  4.29259332e-01,  2.07609147e-02,
#         -1.54242258e-01, -3.12706794e-01, -4.91074369e-02,
#          4.59319956e-01, -1.16886495e+00],
#        [ 3.09927582e-01, -1.31581728e+00,  2.61510651e-01,
#         -1.58336632e-01,  1.33904382e+00,  1.38360116e-02,
#         -1.08750710e-01,  2.31320955e-01],
#        [-9.49095924e-02, -9.19208961e-01,  1.83701884e+00,
#          1.82655633e+00, -4.90132691e-01, -9.32867609e-02,
#         -8.45834135e-01,  1.52686663e+00]])

# %%
np.max(X_train)
# Out:
# 96.67068422289202

# %%
X_train.shape
# Out:
# (11610, 8)

# %%
model = keras.models.Sequential([
    keras.layers.Dense(30, activation="relu", input_shape=X_train.shape[1:]),
    keras.layers.Dense(1)
])

# %%
model.compile(loss='mean_squared_error', optimizer='sgd')

# %%
history = model.fit(X_train, y_train, epochs=20,
                   validation_data=(X_valid, y_valid))
# Out:
# Train on 11610 samples, validate on 3870 samples
# Epoch 1/20
# 11610/11610 [==============================] - 0s 34us/sample - loss: 0.9492 - val_loss: 2.0072
# Epoch 2/20
# 11610/11610 [==============================] - 0s 22us/sample - loss: 0.8702 - val_loss: 0.4713
# Epoch 3/20
# 11610/11610 [==============================] - 0s 21us/sample - loss: 0.4949 - val_loss: 0.4675
# Epoch 4/20
# 11610/11610 [==============================] - 0s 21us/sample - loss: 0.4644 - val_loss: 0.4864
# Epoch 5/20
# 11610/11610 [==============================] - 0s 21us/sample - loss: 0.4388 - val_loss: 0.5678
# Epoch 6/20
# 11610/11610 [==============================] - 0s 21us/sample - loss: 0.4323 - val_loss: 0.6054
# Epoch 7/20
# 11610/11610 [==============================] - 0s 23us/sample - loss: 0.4185 - val_loss: 0.7575
# Epoch 8/20
# 11610/11610 [==============================] - 0s 22us/sample - loss: 0.4093 - val_loss: 0.8364
# Epoch 9/20
# 11610/11610 [==============================] - 0s 22us/sample - loss: 0.4049 - val_loss: 0.9456
# Epoch 10/20
# 11610/11610 [==============================] - 0s 22us/sample - loss: 0.4108 - val_loss: 1.0050
# Epoch 11/20
# 11610/11610 [==============================] - 0s 22us/sample - loss: 0.3992 - val_loss: 1.1780
# Epoch 12/20
# 11610/11610 [==============================] - 0s 22us/sample - loss: 0.3930 - val_loss: 1.3263
# Epoch 13/20
# 11610/11610 [==============================] - 0s 21us/sample - loss: 0.3918 - val_loss: 1.4299
# Epoch 14/20
# 11610/11610 [==============================] - 0s 21us/sample - loss: 0.3849 - val_loss: 1.5512
# Epoch 15/20
# 11610/11610 [==============================] - 0s 22us/sample - loss: 0.3820 - val_loss: 1.7959
# Epoch 16/20
# 11610/11610 [==============================] - 0s 23us/sample - loss: 0.3786 - val_loss: 1.7573
# Epoch 17/20
# 11610/11610 [==============================] - 0s 21us/sample - loss: 0.3745 - val_loss: 1.9913
# Epoch 18/20
# 11610/11610 [==============================] - 0s 21us/sample - loss: 0.3708 - val_loss: 2.0510
# Epoch 19/20
# 11610/11610 [==============================] - 0s 22us/sample - loss: 0.3674 - val_loss: 2.4466
# Epoch 20/20
# 11610/11610 [==============================] - 0s 21us/sample - loss: 0.3650 - val_loss: 2.5345

# %%
history_df = pd.DataFrame(history.history)
history_df.head()
# Out:
#        loss  val_loss
# 0  0.949191  2.007209
# 1  0.870215  0.471296
# 2  0.494906  0.467457
# 3  0.464399  0.486421
# 4  0.438814  0.567772

# %%
history_df.plot()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
mse_test = model.evaluate(X_test, y_test)
# Out:
# 5160/5160 [==============================] - 0s 12us/sample - loss: 0.3815

# %%
mse_test
# Out:
# 0.381471275474674

# %%
model.predict(X_test[:3])
# Out:
# array([[0.9017869],
#        [3.7856488],
#        [3.6141682]], dtype=float32)

# %% [markdown]
# ## Wide and Deep NNs
#
# The below model helps create a neural network where the input is passed to the first hidden layer and is concatenated with the output of the second layer before it connects to the output layer.

# %%
input_ = keras.layers.Input(shape=X_train.shape[1:])
hidden1 = keras.layers.Dense(30, activation="relu")(input_)
hidden2 = keras.layers.Dense(30, activation="relu")(hidden1)
concat = keras.layers.Concatenate()([input_, hidden2])
output = keras.layers.Dense(1)(concat)
model = keras.Model(inputs=[input_], outputs=[output])

# %%
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_4 (InputLayer)            [(None, 8)]          0
# __________________________________________________________________________________________________
# dense_13 (Dense)                (None, 30)           270         input_4[0][0]
# __________________________________________________________________________________________________
# dense_14 (Dense)                (None, 30)           930         dense_13[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 38)           0           input_4[0][0]
#                                                                  dense_14[0][0]
# __________________________________________________________________________________________________
# dense_15 (Dense)                (None, 1)            39          concatenate_3[0][0]
# ==================================================================================================
# Total params: 1,239
# Trainable params: 1,239
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
model.compile(loss='mean_squared_error', optimizer='sgd')

# %%
history = model.fit(X_train, y_train,
                   epochs=30,
                   validation_data=(X_valid, y_valid))
# Out:
# Train on 11610 samples, validate on 3870 samples
# Epoch 1/30
# 11610/11610 [==============================] - 1s 45us/sample - loss: 2.2182 - val_loss: 5.1515
# Epoch 2/30
# 11610/11610 [==============================] - 0s 23us/sample - loss: 32.4384 - val_loss: 16.7138
# Epoch 3/30
# 11610/11610 [==============================] - 0s 23us/sample - loss: nan - val_loss: nan
# Epoch 4/30
# 11610/11610 [==============================] - 0s 23us/sample - loss: nan - val_loss: nan
# Epoch 5/30
# 11610/11610 [==============================] - 0s 22us/sample - loss: nan - val_loss: nan
# Epoch 6/30
# 11610/11610 [==============================] - 0s 23us/sample - loss: nan - val_loss: nan
# Epoch 7/30
# 11610/11610 [==============================] - 0s 23us/sample - loss: nan - val_loss: nan
# Epoch 8/30
# 11610/11610 [==============================] - 0s 23us/sample - loss: nan - val_loss: nan
# Epoch 9/30
# 11610/11610 [==============================] - 0s 24us/sample - loss: nan - val_loss: nan
# Epoch 10/30
# 11610/11610 [==============================] - 0s 23us/sample - loss: nan - val_loss: nan
# Epoch 11/30
# 11610/11610 [==============================] - 0s 23us/sample - loss: nan - val_loss: nan
# Epoch 12/30
# 11610/11610 [==============================] - 0s 23us/sample - loss: nan - val_loss: nan
# Epoch 13/30
# 11610/11610 [==============================] - 0s 23us/sample - loss: nan - val_loss: nan
# Epoch 14/30
# 11610/11610 [==============================] - 0s 23us/sample - loss: nan - val_loss: nan
# Epoch 15/30
# 11610/11610 [==============================] - 0s 24us/sample - loss: nan - val_loss: nan
# Epoch 16/30
# 11610/11610 [==============================] - 0s 26us/sample - loss: nan - val_loss: nan
# Epoch 17/30
# 11610/11610 [==============================] - 0s 23us/sample - loss: nan - val_loss: nan
# Epoch 18/30
# 11610/11610 [==============================] - 0s 24us/sample - loss: nan - val_loss: nan
# Epoch 19/30
# 11610/11610 [==============================] - 0s 24us/sample - loss: nan - val_loss: nan
# Epoch 20/30
# 11610/11610 [==============================] - 0s 23us/sample - loss: nan - val_loss: nan
# Epoch 21/30
# 11610/11610 [==============================] - 0s 23us/sample - loss: nan - val_loss: nan
# Epoch 22/30
# 11610/11610 [==============================] - 0s 25us/sample - loss: nan - val_loss: nan
# Epoch 23/30
# 11610/11610 [==============================] - 0s 24us/sample - loss: nan - val_loss: nan
# Epoch 24/30
# 11610/11610 [==============================] - 0s 23us/sample - loss: nan - val_loss: nan
# Epoch 25/30
# 11610/11610 [==============================] - 0s 23us/sample - loss: nan - val_loss: nan
# Epoch 26/30
# 11610/11610 [==============================] - 0s 24us/sample - loss: nan - val_loss: nan
# Epoch 27/30
# 11610/11610 [==============================] - 0s 23us/sample - loss: nan - val_loss: nan
# Epoch 28/30
# 11610/11610 [==============================] - 0s 25us/sample - loss: nan - val_loss: nan
# Epoch 29/30
# 11610/11610 [==============================] - 0s 24us/sample - loss: nan - val_loss: nan
# Epoch 30/30
# 11610/11610 [==============================] - 0s 25us/sample - loss: nan - val_loss: nan
